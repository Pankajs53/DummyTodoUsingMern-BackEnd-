# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('XpathData.csv')
df
# Out:
#             State                                               Link
# 0            Agra  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 1       Ahmedabad  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 2           Ajmer  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 3       Alappuzha  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 4       Allahabad  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# ..            ...                                                ...
# 80        Vadodra  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 81       Varanasi  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 82        Vellore  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 83      Vijaywada  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
# 84  Visakhapatnam  //*[@id="root"]/div/div[4]/div[3]/div/div/div/...
#
# [85 rows x 2 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# Set the folder path to save the HTML files
folder_path = r"C:\Users\312tx asus\Desktop\Faltu Projects\web scrapping\All HTML"

# Assuming you have the state-link mapping stored in a DataFrame called 'df'

# Iterate over the rows of the DataFrame and save HTML for each state
for _, row in df.iterrows():
    state = row['State']
    link = row['Link']
    print("In",state)
    
    s = Service('C:/Users/312tx asus/Desktop/Web Scrapping/chrome driver/chromedriver.exe')
    driver = webdriver.Chrome(service=s)
    driver.get('https://www.zomato.com/india')
    driver.find_element(by=By.XPATH, value=link).click()

    old_height = driver.execute_script('return document.body.scrollHeight')
    counter = 1
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
        time.sleep(2)

        new_height = driver.execute_script('return document.body.scrollHeight')

        print(old_height)
        print(new_height)
        print(counter)
        counter += 1

        if new_height == old_height:
            break
        old_height = new_height

    html = driver.page_source
    
    # Generate the file path
    filename = f"{state.lower()}.html"
    file_path = os.path.join(folder_path, filename)
    
    # Save the HTML content to the file
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(html)
    
    # Close the browser
    driver.quit()
# Out:
# In Agra
# 4316
# 7636
# 1
# 7636
# 10956
# 2
# 10956
# 14276
# 3
# 14276
# 17546
# 4
# 17546
# 20887
# 5
# 20887
# 24207
# 6
# 24207
# 27527
# 7
# 27527
# 30847
# 8
# 30847
# 34117
# 9
# 34117
# 35777
# 10
# 35777
# 39097
# 11
# 39097
# 42367
# 12
# 42367
# 45587
# 13
# 45587
# 47247
# 14
# 47247
# 50517
# 15
# 50517
# 53837
# 16
# 53837
# 57057
# 17
# 57057
# 60327
# 18
# 60327
# 63447
# 19
# 63447
# 65107
# 20
# 65107
# 68327
# 21
# 68327
# 71447
# 22
# 71447
# 74617
# 23
# 74617
# 76227
# 24
# 76227
# 79447
# 25
# 79447
# 82617
# 26
# 82617
# 84177
# 27
# 84177
# 87297
# 28
# 87297
# 90467
# 29
# 90467
# 91977
# 30
# 91977
# 95097
# 31
# 95097
# 98417
# 32
# 98417
# 99927
# 33
# 99927
# 106369
# 34
# 106369
# 109907
# 35
# 109907
# 112128
# 36
# 112128
# 112128
# 37
# In Ahmedabad
# 4390
# 6050
# 1
# 6050
# 9370
# 2
# 9370
# 12690
# 3
# 12690
# 14350
# 4
# 14350
# 17670
# 5
# 17670
# 20990
# 6
# 20990
# 24310
# 7
# 24310
# 27630
# 8
# 27630
# 29290
# 9
# 29290
# 32610
# 10
# ...

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
import os

folder_path = r"C:\Users\312tx asus\Desktop\Faltu Projects\web scrapping\All HTML"  # Replace with the path to your folder

file_paths = []

# Iterate over all files in the folder and its subfolders
for root, dirs, files in os.walk(folder_path):
    for file in files:
        file_path = os.path.join(root, file)
        file_paths.append(file_path)

# Print the extracted file paths
#for i in file_paths:
#    print(i)

# %%
for filepath in file_paths:
    filename = os.path.splitext(os.path.basename(filepath))[0]
    with open(filepath, 'r', encoding='utf-8') as f:
        html = f.read()
        
    soup = BeautifulSoup(html, 'lxml') 
    
    container = soup.find_all('div', {'class': ['sc-kREsUy fxbqJz', 'sc-kREsUy hsgHbN', 'sc-dzOgQY hBUHjQ', 'sc-dzOgQY fnDzyq','sc-jaqGxO jNFjRR', 'sc-kqqoiJ geaubH', 'sc-kqqoiJ kYaJMW', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-wzDOX diLGUw', 'sc-wzDOX eszeNl', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-cmUJln cGQVnf', 'sc-cmUJln eqDhrA', 'sc-hAnkBK wIvRm', 'sc-gTAwTn evRbHK', 'sc-jlBbkx dPDPLV']})
      
    count = 0
    for i in container:
        print(i.find('h4').text)
        print(i.find('p',{'class':['sc-1hez2tp-0 sc-hULAQv dqdZrg','sc-1hez2tp-0 sc-hULAQv htXapO']}).text)
        print(i.find('div',{'class':'sc-1q7bklc-1 cILgox'}).text)
            
        
    if count >= 100:
        print(filename, count)
# Out:
# Pizza Hut
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 13
#      11 for i in container:
#      12     print(i.find('h4').text)
# ---> 13     print(i.find('p',{'class':['sc-1hez2tp-0 sc-hULAQv dqdZrg','sc-1hez2tp-0 sc-hULAQv htXapO']}).text)
#      14     print(i.find('div',{'class':'sc-1q7bklc-1 cILgox'}).text)
#      17 if count >= 100:
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for filepath in file_paths:
    filename = os.path.splitext(os.path.basename(filepath))[0]
    with open(filepath, 'r', encoding='utf-8') as f:
        html = f.read()

    soup = BeautifulSoup(html, 'lxml')

    container = soup.find_all('div', {'class': ['sc-kREsUy fxbqJz', 'sc-kREsUy hsgHbN','sc-jaqGxO jNFjRR', 'sc-dzOgQY hBUHjQ', 'sc-dzOgQY fnDzyq', 'sc-kqqoiJ geaubH', 'sc-kqqoiJ kYaJMW', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-wzDOX diLGUw', 'sc-wzDOX eszeNl', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-cmUJln cGQVnf', 'sc-cmUJln eqDhrA', 'sc-hAnkBK wIvRm', 'sc-gTAwTn evRbHK', 'sc-jlBbkx dPDPLV']})

    count = 0
    for i in container:
        restaurant_name = i.find('h4').text
        restaurant_info_element = i.find('p', {'class': ['sc-1hez2tp-0 sc-hULAQv dqdZrg', 'sc-1hez2tp-0 sc-hULAQv htXapO','sc-cXIWzj hMlgHL']})
        restaurant_info = restaurant_info_element.text if restaurant_info_element else "No information available"
        restaurant_details_element = i.find('div', {'class': 'sc-1q7bklc-1 cILgox'})
        restaurant_details = restaurant_details_element.text if restaurant_details_element else "No details available"

        # Print the restaurant name, info, and details
        print("Restaurant Name:", restaurant_name)
        print("Restaurant Info:", restaurant_info)
        print("Restaurant Details:", restaurant_details)
        print()

        count += 1
        
        if count >= 100:
            print(filename, count)
            break
# Out:
# Restaurant Name: Pizza Hut
# Restaurant Info: No information available
# Restaurant Details: 3.8
#
# Restaurant Name: GMB - Gopika Sweets & Restaurant
# Restaurant Info: No information available
# Restaurant Details: 4.2
#
# Restaurant Name: Bhagat Halwai
# Restaurant Info: No information available
# Restaurant Details: 3.9
#
# Restaurant Name: Bapu Dhaba
# Restaurant Info: No information available
# Restaurant Details: 3.6
#
# Restaurant Name: Bikanervala
# Restaurant Info: No information available
# Restaurant Details: 4.0
#
# Restaurant Name: Shri Tirupati No.1 Family Restaurant
# Restaurant Info: No information available
# Restaurant Details: 3.8
#
# Restaurant Name: Star Ultimate Pizza
# Restaurant Info: No information available
# Restaurant Details: 4.0
#
# Restaurant Name: Cake House
# Restaurant Info: No information available
# Restaurant Details: 3.5
#
# Restaurant Name: Bhagat Halwai
# Restaurant Info: No information available
# Restaurant Details: 3.9
#
# ...

# %%
for filepath in file_paths:
    filename = os.path.splitext(os.path.basename(filepath))[0]
    with open(filepath, 'r', encoding='utf-8') as f:
        html = f.read()

    soup = BeautifulSoup(html, 'lxml')

    container = soup.find_all('div', {'class': ['sc-kREsUy fxbqJz', 'sc-kREsUy hsgHbN', 'sc-dzOgQY hBUHjQ', 'sc-dzOgQY fnDzyq', 'sc-kqqoiJ geaubH', 'sc-kqqoiJ kYaJMW', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-wzDOX diLGUw', 'sc-wzDOX eszeNl', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-cmUJln cGQVnf', 'sc-cmUJln eqDhrA', 'sc-hAnkBK wIvRm', 'sc-gTAwTn evRbHK', 'sc-jlBbkx dPDPLV']})

    count = 0
    for i in container:
        restaurant_name = i.find('h4').text
        restaurant_info_element = i.find('p', {'class': ['sc-1hez2tp-0 sc-hULAQv dqdZrg', 'sc-1hez2tp-0 sc-hULAQv htXapO']})
        restaurant_info = restaurant_info_element.text if restaurant_info_element else "No information available"
        restaurant_details_element = i.find('div', {'class': 'sc-1q7bklc-1 cILgox'})
        restaurant_details = restaurant_details_element.text if restaurant_details_element else "No details available"
        
        inner_div_element = i.find('div', {'class': 'sc-cXIWzj hMlgHL'})
        inner_p_element = inner_div_element.find('p', {'class': 'sc-1hez2tp-0 sc-hULAQv dqdZrg'}) if inner_div_element else None
        inner_p_text = inner_p_element.text if inner_p_element else "No additional text available"

        # Print the restaurant name, info, details, and additional text
        print("Restaurant Name:", restaurant_name)
        print("Restaurant Info:", restaurant_info)
        print("Restaurant Details:", restaurant_details)
        print("Additional Text:", inner_p_text)
        print()

        count += 1
        
        if count >= 100:
            print(filename, count)
            break
# Out:
# Restaurant Name: Pizza Hut
# Restaurant Info: No information available
# Restaurant Details: 3.8
# Additional Text: No additional text available
#
# Restaurant Name: GMB - Gopika Sweets & Restaurant
# Restaurant Info: No information available
# Restaurant Details: 4.2
# Additional Text: No additional text available
#
# Restaurant Name: Bhagat Halwai
# Restaurant Info: No information available
# Restaurant Details: 3.9
# Additional Text: No additional text available
#
# Restaurant Name: Bapu Dhaba
# Restaurant Info: No information available
# Restaurant Details: 3.6
# Additional Text: No additional text available
#
# Restaurant Name: Bikanervala
# Restaurant Info: No information available
# Restaurant Details: 4.0
# Additional Text: No additional text available
#
# Restaurant Name: Shri Tirupati No.1 Family Restaurant
# Restaurant Info: No information available
# Restaurant Details: 3.8
# Additional Text: No additional text available
#
# Restaurant Name: Star Ultimate Pizza
# ...

# %%
for i in container3:
    count += 1
    print(i.find('h4').text)
    
    p_element = i.find('div', {'class': 'sc-vBKru khAcxg'})
    if p_element is not None:
        print(p_element.text)
    else:
        print("No matching <p> element found.")
        
    div_element = i.find('div', {'class': 'sc-vBKru khAcxg'})
    if div_element is not None:
        print(div_element.text)
    else:
        print("No matching <div> element found.")
            
        
print("Debug: Count for", filename, "=", count)  # Debug statement
if count < 10:
    print(filename, count)
else:
    print(count)
# Out:
# Pizza Hut
# Pizza Hut3.8star-fill
# Pizza Hut3.8star-fill
# GMB - Gopika Sweets & Restaurant
# GMB - Gopika Sweets & Restaurant4.2star-fill
# GMB - Gopika Sweets & Restaurant4.2star-fill
# Bhagat Halwai
# Bhagat Halwai3.9star-fill
# Bhagat Halwai3.9star-fill
# Bapu Dhaba
# Bapu Dhaba3.6star-fill
# Bapu Dhaba3.6star-fill
# Bikanervala
# Bikanervala4.0star-fill
# Bikanervala4.0star-fill
# Shri Tirupati No.1 Family Restaurant
# Shri Tirupati No.1 Family Restaurant3.8star-fill
# Shri Tirupati No.1 Family Restaurant3.8star-fill
# Star Ultimate Pizza
# Star Ultimate Pizza4.0star-fill
# Star Ultimate Pizza4.0star-fill
# Cake House
# Cake House3.5star-fill
# Cake House3.5star-fill
# Bhagat Halwai
# Bhagat Halwai3.9star-fill
# Bhagat Halwai3.9star-fill
# Shiv Bhojnalaya
# Shiv Bhojnalaya3.6star-fill
# Shiv Bhojnalaya3.6star-fill
# Chokho Jeeman Marwari Jain Bhojanalya
# Chokho Jeeman Marwari Jain Bhojanalya4.3star-fill
# Chokho Jeeman Marwari Jain Bhojanalya4.3star-fill
# ...

# %%
for filepath in file_paths:
    filename = os.path.splitext(os.path.basename(filepath))[0]
    with open(filepath, 'r', encoding='utf-8') as f:
        html = f.read()

    soup = BeautifulSoup(html, 'lxml')

    container = soup.find_all('div', {'class': ['sc-kREsUy fxbqJz', 'sc-kREsUy hsgHbN', 'sc-dzOgQY hBUHjQ', 'sc-dzOgQY fnDzyq', 'sc-kqqoiJ geaubH', 'sc-kqqoiJ kYaJMW', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-wzDOX diLGUw', 'sc-wzDOX eszeNl', 'sc-hAnkBK wIvRm', 'sc-hAnkBK eTKLlP', 'sc-cmUJln cGQVnf', 'sc-cmUJln eqDhrA', 'sc-hAnkBK wIvRm', 'sc-gTAwTn evRbHK', 'sc-jlBbkx dPDPLV']})

    for i in container:
        restaurant_name = i.find('h4').text
        restaurant_info = i.find('div', {'class': 'sc-1hez2tp-0 sc-hULAQv dqdZrg'}).text

        # Print the restaurant name and info
        print("Restaurant Name:", restaurant_name)
        print("Restaurant Info:", restaurant_info)
        print()

        # Get the restaurant details
        restaurant_details = i.find('div', {'class': 'rest-info-highlights'}).text

        # Print the restaurant details
        print("Restaurant Details:")
        print(restaurant_details)
        print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 12
#      10 for i in container:
#      11     restaurant_name = i.find('h4').text
# ---> 12     restaurant_info = i.find('div', {'class': 'sc-1hez2tp-0 sc-hULAQv dqdZrg'}).text
#      14     # Print the restaurant name and info
#      15     print("Restaurant Name:", restaurant_name)
#
# AttributeError: 'NoneType' object has no attribute 'text'
